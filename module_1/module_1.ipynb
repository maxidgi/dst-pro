# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import datetime
import itertools

# %%
data = pd.read_csv('movie_bd_v5.csv')
display(data.info())
display(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   object
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
# dtypes: float64(1), int64(4), object(9)
# ...

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

data['profit'] = data.revenue - data.budget

data['director_item'] = data.director.str.split('|')

data['genre_item'] = data.genres.str.split('|')

data['cast_item'] = data.cast.str.split('|')

data['company_item'] = data.production_companies.str.split('|')

data.release_date = pd.to_datetime(data.release_date)

data['original_title_len'] = data.original_title.apply(lambda x : len(x))

data['overview_len'] = data.overview.apply(lambda x : len(x))

display(data)

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
# answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
data.sort_values('budget', ascending = False)
# Out:
#         imdb_id     budget     revenue  \
# 723   tt1298650  380000000  1021683000
# 1669  tt0449088  300000000   961000000
# 14    tt2395427  280000000  1405035767
# 1014  tt0401729  260000000   284139100
# 380   tt0398286  260000000   591794936
# ...         ...        ...         ...
# 885   tt0283111    5000000    38275483
# 892   tt0259446    5000000   368744044
# 1071  tt2109184    5000000   142817992
# 911   tt0322802    5000000    64282312
# 1216  tt2101441    5000000    31724284
#
#                                    original_title  \
# 723   Pirates of the Caribbean: On Stranger Tides
# 1669     Pirates of the Caribbean: At World's End
# 14                        Avengers: Age of Ultron
# 1014                                  John Carter
# 380                                       Tangled
# ...                                           ...
# 885               National Lampoonâ€™s Van Wilder
# 892                      My Big Fat Greek Wedding
# ...

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '2. Gods and Generals (tt0279111)'

# %%
data.sort_values('runtime', ascending = False)
# Out:
#         imdb_id     budget     revenue  \
# 1157  tt0279111   56000000    12923936
# 1081  tt0167260   94000000  1118888979
# 1736  tt0462322   67000000    25037897
# 1336  tt0360717  207000000   550000000
# 504   tt0213149  140000000   449220945
# ...         ...        ...         ...
# 1408  tt0361089   35000000    19478106
# 1626  tt0299172  110000000   103951461
# 1097  tt0283426   20000000   135680000
# 930   tt0280030   20000000   109862682
# 768   tt1449283   30000000    14460000
#
#                                      original_title  \
# 1157                              Gods and Generals
# 1081  The Lord of the Rings: The Return of the King
# 1736                                     Grindhouse
# 1336                                      King Kong
# 504                                    Pearl Harbor
# ...                                             ...
# 1408                                        Valiant
# 1626                              Home on the Range
# ...

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '3. Winnie the Pooh (tt1449283)'

# %%
data.sort_values('runtime')
# Out:
#         imdb_id     budget     revenue  \
# 768   tt1449283   30000000    14460000
# 930   tt0280030   20000000   109862682
# 1097  tt0283426   20000000   135680000
# 1408  tt0361089   35000000    19478106
# 1626  tt0299172  110000000   103951461
# ...         ...        ...         ...
# 504   tt0213149  140000000   449220945
# 1336  tt0360717  207000000   550000000
# 1736  tt0462322   67000000    25037897
# 1081  tt0167260   94000000  1118888979
# 1157  tt0279111   56000000    12923936
#
#                                      original_title  \
# 768                                 Winnie the Pooh
# 930                            Return to Never Land
# 1097                              The Jungle Book 2
# 1408                                        Valiant
# 1626                              Home on the Range
# ...                                             ...
# 504                                    Pearl Harbor
# 1336                                      King Kong
# ...

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '2. 110'

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '1. 107'

# %%
data.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = '5. Avatar (tt0499549)'

# %%
data.sort_values('profit', ascending = False)
# Out:
#         imdb_id     budget     revenue                original_title  \
# 239   tt0499549  237000000  2781505847                        Avatar
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 0     tt0369610  150000000  1513528810                Jurassic World
# 4     tt2820852  190000000  1506249360                     Furious 7
# 970   tt0848228  220000000  1519557910                  The Avengers
# ...         ...        ...         ...                           ...
# 1464  tt0424095  149000000    64459316                  Flushed Away
# 958   tt0180052  100000000     7103973  The Adventures of Pluto Nash
# 809   tt1305591  150000000    38992758               Mars Needs Moms
# 1616  tt0318974  145000000    25819961                     The Alamo
# 1245  tt1210819  255000000    89289910               The Lone Ranger
#
#                                                    cast  \
# 239   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# ...

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '5. The Lone Ranger (tt1210819)'

# %%
data.sort_values('profit')
# Out:
#         imdb_id     budget     revenue                original_title  \
# 1245  tt1210819  255000000    89289910               The Lone Ranger
# 1616  tt0318974  145000000    25819961                     The Alamo
# 809   tt1305591  150000000    38992758               Mars Needs Moms
# 958   tt0180052  100000000     7103973  The Adventures of Pluto Nash
# 1464  tt0424095  149000000    64459316                  Flushed Away
# ...         ...        ...         ...                           ...
# 970   tt0848228  220000000  1519557910                  The Avengers
# 4     tt2820852  190000000  1506249360                     Furious 7
# 0     tt0369610  150000000  1513528810                Jurassic World
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 239   tt0499549  237000000  2781505847                        Avatar
#
#                                                    cast  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...
# ...

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1. 1478'

# %%
data[data.profit > 0].imdb_id.count()
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '4. The Dark Knight (tt0468569)'

# %%
data[data.release_year == 2008].sort_values('profit', ascending = False)
# Out:
#        imdb_id     budget     revenue  \
# 599  tt0468569  185000000  1001921825
# 603  tt0367882  185000000   786636033
# 607  tt0795421   52000000   609841637
# 606  tt0441773  130000000   631744560
# 621  tt0448157  150000000   624029371
# ..         ...        ...         ...
# 668  tt0811080  120000000    93945766
# 705  tt0469903   40000000     9793496
# 682  tt0970411   55000000    17869048
# 679  tt0462465   50000000     7033683
# 636  tt0455824  130000000    49554002
#
#                                         original_title  \
# 599                                    The Dark Knight
# 603  Indiana Jones and the Kingdom of the Crystal S...
# 607                                         Mamma Mia!
# 606                                      Kung Fu Panda
# 621                                            Hancock
# ..                                                 ...
# 668                                        Speed Racer
# ...

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '5. The Lone Ranger (tt1210819)'

# %%
data[(data.release_year >= 2012) & (data.release_year <= 2014)].sort_values('profit')
# Out:
#         imdb_id     budget     revenue                   original_title  \
# 1245  tt1210819  255000000    89289910                  The Lone Ranger
# 1214  tt0790736  130000000    61648500                         R.I.P.D.
# 1007  tt1374992   60000000     8106475                      Upside Down
# 1302  tt0884726   70000000    18662027  Legends of Oz: Dorothy's Return
# 1235  tt1308729   55000000     9489829               Bullet to the Head
# ...         ...        ...         ...                              ...
# 1189  tt1690953   76000000   970761885                  Despicable Me 2
# 974   tt1074638  200000000  1108561013                          Skyfall
# 1180  tt1300854  200000000  1215439994                       Iron Man 3
# 1177  tt2294629  150000000  1274219009                           Frozen
# 970   tt0848228  220000000  1519557910                     The Avengers
#
#                                                    cast  \
# ...

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = '3. Drama'

# %%
data.explode('genre_item').genre_item.value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: genre_item, dtype: int64

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = '1. Drama'

# %%
data['genre_item'] = data.genres.str.split('|')
data.explode('genre_item').query('profit > 0').genre_item.value_counts()
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genre_item, dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = '5. Peter Jackson'

# %%
data.explode('director_item').groupby(['director_item'])['revenue'].sum().sort_values(ascending=False)
# Out:
# director_item
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 997, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = '3. Robert Rodriguez'

# %%
data[data.genres.str.contains('Action')].explode('director_item').director_item.value_counts()
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Oliver Stone          1
# John Erick Dowdle     1
# Philip Kaufman        1
# Stuart Beattie        1
# Jon Avnet             1
# Name: director_item, Length: 364, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = '3. Chris Hemsworth'

# %%
data[data.release_year == 2012].explode('cast_item').groupby(['cast_item'])['revenue'].sum().sort_values(ascending=False)
# Out:
# cast_item
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Chris Evans          1519557910
# Robert Downey Jr.    1519557910
#                         ...
# Jason Bateman           3428048
# Danny Huston            2106557
# Sami Gayle              2106557
# Josh Lucas              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = '3. Matt Damon'

# %%
data[data.budget > data.budget.mean()].explode('cast_item').cast_item.value_counts()
# Out:
# Matt Damon                18
# Adam Sandler              17
# Angelina Jolie            16
# Eddie Murphy              15
# Samuel L. Jackson         15
#                           ..
# Peter Mullan               1
# Robert Sheehan             1
# Aishwarya Rai Bachchan     1
# Joseph Fiennes             1
# Jake Thomas                1
# Name: cast_item, Length: 1505, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = '2. Action'

# %%
data[data.cast.str.contains('Nicolas Cage')].explode('genre_item').genre_item.value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Mystery             3
# Family              3
# Animation           3
# History             2
# Horror              1
# War                 1
# Romance             1
# Name: genre_item, dtype: int64

# %%
nc_filtered = data[data.cast.str.contains('Nicolas Cage')]

genres = nc_filtered.genres.str.cat(sep = '|').split('|')

cnt = Counter()
for genre in genres:
    cnt[genre] += 1
cnt
# Out:
# Counter({'Thriller': 15,
#          'Action': 17,
#          'Science Fiction': 4,
#          'Adventure': 7,
#          'Drama': 12,
#          'Mystery': 3,
#          'Crime': 10,
#          'Animation': 3,
#          'Family': 3,
#          'Fantasy': 8,
#          'Comedy': 6,
#          'History': 2,
#          'War': 1,
#          'Horror': 1,
#          'Romance': 1})

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = '1. K-19: The Widowmaker (tt0267626)'

# %%
data.explode('company_item').query('company_item == "Paramount Pictures"').sort_values('profit')
# Out:
#         imdb_id     budget     revenue  \
# 925   tt0267626  100000000    35168966
# 1123  tt0300556   80000000    19480739
# 1722  tt0435705   70000000    18211013
# 1623  tt0375173   60000000    13395939
# 1631  tt0315297   50000000    25195000
# ...         ...        ...         ...
# 730   tt1229238  145000000   694713380
# 1738  tt0418279  150000000   709709780
# 603   tt0367882  185000000   786636033
# 317   tt1055369  150000000   836297228
# 828   tt1399103  195000000  1123746996
#
#                                          original_title  \
# 925                                K-19: The Widowmaker
# 1123                                           Timeline
# 1722                                               Next
# 1623                                              Alfie
# 1631                                            Twisted
# ...                                                 ...
# 730                Mission: Impossible - Ghost Protocol
# ...

# %%
data[data.production_companies.str.contains('Paramount Pictures')].sort_values('profit')
# Out:
#         imdb_id     budget     revenue  \
# 925   tt0267626  100000000    35168966
# 1123  tt0300556   80000000    19480739
# 1722  tt0435705   70000000    18211013
# 1623  tt0375173   60000000    13395939
# 1631  tt0315297   50000000    25195000
# ...         ...        ...         ...
# 730   tt1229238  145000000   694713380
# 1738  tt0418279  150000000   709709780
# 603   tt0367882  185000000   786636033
# 317   tt1055369  150000000   836297228
# 828   tt1399103  195000000  1123746996
#
#                                          original_title  \
# 925                                K-19: The Widowmaker
# 1123                                           Timeline
# 1722                                               Next
# 1623                                              Alfie
# 1631                                            Twisted
# ...                                                 ...
# 730                Mission: Impossible - Ghost Protocol
# ...

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '5. 2015'

# %%
data.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '1. 2014'

# %%
data[data.production_companies.str.contains('Warner Bros')].groupby(['release_year'])['profit'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = '4. Сентябрь'

# %%
data.release_date.dt.month.value_counts()
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: release_date, dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '2. 450'

# %%
data[data.release_date.dt.month.isin(['6','7','8'])].imdb_id.count()
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = '5. Peter Jackson'

# %%
data[data.release_date.dt.month.isin(['12','1','2'])].explode('director_item').director_item.value_counts()
# Out:
# Peter Jackson        7
# Clint Eastwood       6
# Steven Soderbergh    6
# Shawn Levy           4
# Nancy Meyers         4
#                     ..
# David Moreau         1
# Cory Edwards         1
# John Erick Dowdle    1
# J. Mackye Gruber     1
# Robin Budd           1
# Name: director_item, Length: 358, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = '5. Four By Two Productions'

# %%
data.explode('company_item').groupby(['company_item'])['original_title_len'].mean().sort_values(ascending=False)
# Out:
# company_item
# Four By Two Productions       83.0
# Jim Henson Company, The       59.0
# Dos Corazones                 47.0
# Museum Canada Productions     46.0
# Polsky Films                  46.0
#                               ...
# Everest Entertainment          3.0
# Berlanti Productions           3.0
# XM2 Productions                2.0
# Ixtlan Productions             2.0
# Global Entertainment Group     2.0
# Name: original_title_len, Length: 1771, dtype: float64

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = '3. Midnight Picture Show'

# %%
data.explode('company_item').groupby(['company_item'])['overview_len'].mean().sort_values(ascending=False)
# Out:
# company_item
# Midnight Picture Show                    1000.0
# Room 9 Entertainment                      964.0
# Brookwell-McNamara Entertainment          936.0
# Lions Gate Family Entertainment           909.0
# Crest Animation Productions               909.0
#                                           ...
# Projection Pictures                        74.0
# London Boulevard                           74.0
# Phantom Four                               72.0
# Empire Pictures                            62.0
# Motion Picture Corporation of America      59.0
# Name: overview_len, Length: 1771, dtype: float64

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = '1. Inside Out, The Dark Knight, 12 Years a Slave'

# %%
data[data.vote_average > data['vote_average'].quantile(q = 0.99)]
# Out:
#         imdb_id     budget     revenue  \
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 118   tt0816692  165000000   621752480
# 119   tt2015381  170000000   773312399
# 125   tt2084970   14000000   233555708
# 128   tt2267998   61000000   369330363
# 138   tt2278388   30000000   174600318
# 370   tt1375666  160000000   825500000
# 599   tt0468569  185000000  1001921825
# 872   tt0253474   35000000   120072577
# 1081  tt0167260   94000000  1118888979
# 1183  tt0993846  100000000   392000694
# 1191  tt2024544   20000000   187000000
# 1800  tt0209144    9000000    39723096
#
#                                      original_title  \
# 9                                        Inside Out
# 34                                             Room
# 118                                    Interstellar
# 119                         Guardians of the Galaxy
# 125                              The Imitation Game
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %%
answers['27'] = '5. Daniel Radcliffe & Rupert Grint'

# %%
data['cast_pairs'] = data['cast_item'].apply(lambda x: list(itertools.combinations(x, 2)))
data.explode('cast_pairs').cast_pairs.value_counts()
# Out:
# (Daniel Radcliffe, Emma Watson)        8
# (Daniel Radcliffe, Rupert Grint)       8
# (Rupert Grint, Emma Watson)            7
# (Johnny Depp, Helena Bonham Carter)    6
# (Ben Stiller, Owen Wilson)             6
#                                       ..
# (Lizzy Caplan, Clark Duke)             1
# (Cedric the Entertainer, Eve)          1
# (Alessandro Nivola, Gary Lewis)        1
# (Diane Keaton, Keanu Reeves)           1
# (Ned Beatty, Bill Nighy)               1
# Name: cast_pairs, Length: 18121, dtype: int64

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals (tt0279111)',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107',
#  '6': '5. Avatar (tt0499549)',
#  '7': '5. The Lone Ranger (tt1210819)',
#  '8': '1. 1478',
#  '9': '4. The Dark Knight (tt0468569)',
#  '10': '5. The Lone Ranger (tt1210819)',
#  '11': '3. Drama',
#  '12': '1. Drama',
#  '13': '5. Peter Jackson',
#  '14': '3. Robert Rodriguez',
#  '15': '3. Chris Hemsworth',
#  '16': '3. Matt Damon',
#  '17': '2. Action',
#  '18': '1. K-19: The Widowmaker (tt0267626)',
#  '19': '5. 2015',
#  '20': '1. 2014',
#  '21': '4. Сентябрь',
#  '22': '2. 450',
#  '23': '5. Peter Jackson',
#  '24': '5. Four By Two Productions',
#  '25': '3. Midnight Picture Show',
#  '26': '1. Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': '5. Daniel Radcliffe & Rupert Grint'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
